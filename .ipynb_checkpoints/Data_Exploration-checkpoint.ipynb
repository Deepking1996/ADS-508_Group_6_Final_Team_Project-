# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd
import numpy as np

# %%
housing = pd.read_csv("housing.csv")
hpi = pd.read_csv("hpi_master (1).csv")

race = pd.read_excel("Race.xlsx")
age_sex = pd.read_excel("Resident Population by Age and Sex.xlsx")
population = pd.read_excel("Total Population by County.xlsx")

# %%
def explore(df, name):
    print("==============")
    print("Dataset:", name)
    print("==============")
    
    print("\nShape:")
    print(df.shape)
    
    print("\nColumns:")
    print(df.columns)
    
    print("\nData Types:")
    print(df.dtypes)
    
    print("\nMissing Values:")
    print(df.isnull().sum())
    
    print("\nDuplicate Rows:")
    print(df.duplicated().sum())
    
    print("\nSummary Statistics:")
    print(df.describe(include='all'))

# %%
explore(housing, "Housing Data")
explore(hpi, "HPI Data")
explore(race, "Race Data")
explore(age_sex, "Age & Sex Data")
explore(population, "Population Data")
# Out:
# ==============
# Dataset: Housing Data
# ==============
#
# Shape:
# (20640, 10)
#
# Columns:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')
#
# Data Types:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object
#
# Missing Values:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Summary Statistics:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20640.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.639486   2635.763081
# std         2.003532      2.135952           12.585558   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population    households  median_income  \
# count     20433.000000  20640.000000  20640.000000   20640.000000
# unique             NaN           NaN           NaN            NaN
# top                NaN           NaN           NaN            NaN
# freq               NaN           NaN           NaN            NaN
# mean        537.870553   1425.476744    499.539680       3.870671
# std         421.385070   1132.462122    382.329753       1.899822
# min           1.000000      3.000000      1.000000       0.499900
# 25%         296.000000    787.000000    280.000000       2.563400
# 50%         435.000000   1166.000000    409.000000       3.534800
# 75%         647.000000   1725.000000    605.000000       4.743250
# max        6445.000000  35682.000000   6082.000000      15.000100
#
#         median_house_value ocean_proximity
# count         20640.000000           20640
# unique                 NaN               5
# top                    NaN       <1H OCEAN
# freq                   NaN            9136
# mean         206855.816909             NaN
# std          115395.615874             NaN
# min           14999.000000             NaN
# 25%          119600.000000             NaN
# 50%          179700.000000             NaN
# 75%          264725.000000             NaN
# max          500001.000000             NaN
# ==============
# Dataset: HPI Data
# ==============
#
# Shape:
# (133206, 10)
#
# Columns:
# Index(['hpi_type', 'hpi_flavor', 'frequency', 'level', 'place_name',
#        'place_id', 'yr', 'period', 'index_nsa', 'index_sa'],
#       dtype='object')
#
# Data Types:
# hpi_type       object
# hpi_flavor     object
# frequency      object
# level          object
# place_name     object
# place_id       object
# yr              int64
# period          int64
# index_nsa     float64
# index_sa      float64
# dtype: object
#
# Missing Values:
# hpi_type          0
# hpi_flavor        0
# frequency         0
# level             0
# place_name        0
# place_id          0
# yr                0
# period            0
# index_nsa         0
# index_sa      88846
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Summary Statistics:
#            hpi_type        hpi_flavor  frequency   level     place_name  \
# count        133206            133206     133206  133206         133206
# unique            5                 3          2       4            472
# top     traditional  all-transactions  quarterly     MSA  United States
# freq         124967             88742     129006   93203           1112
# mean            NaN               NaN        NaN     NaN            NaN
# std             NaN               NaN        NaN     NaN            NaN
# min             NaN               NaN        NaN     NaN            NaN
# 25%             NaN               NaN        NaN     NaN            NaN
# 50%             NaN               NaN        NaN     NaN            NaN
# 75%             NaN               NaN        NaN     NaN            NaN
# max             NaN               NaN        NaN     NaN            NaN
#
#        place_id             yr         period      index_nsa      index_sa
# count    133206  133206.000000  133206.000000  133206.000000  44360.000000
# unique      472            NaN            NaN            NaN           NaN
# top         USA            NaN            NaN            NaN           NaN
# freq       1112            NaN            NaN            NaN           NaN
# mean        NaN    2005.108584       2.630227     191.168651    215.705577
# std         NaN      12.374372       1.439934     113.231063    110.299762
# min         NaN    1975.000000       1.000000      18.640000     74.690000
# 25%         NaN    1996.000000       2.000000     111.542500    136.127500
# 50%         NaN    2006.000000       3.000000     165.900000    190.065000
# 75%         NaN    2016.000000       4.000000     231.600000    257.992500
# max         NaN    2025.000000      12.000000    1303.960000    819.280000
# ==============
# Dataset: Race Data
# ==============
#
# Shape:
# (44, 2)
#
# Columns:
# Index(['Race', 'Unnamed: 1'], dtype='object')
#
# Data Types:
# Race          object
# Unnamed: 1    object
# dtype: object
#
# Missing Values:
# Race          19
# Unnamed: 1    23
# dtype: int64
#
# Duplicate Rows:
# 9
#
# Summary Statistics:
#                                                      Race Unnamed: 1
# count                                                  25         21
# unique                                                 25         20
# top     Note: The table shown may have been modified b...     B02001
# freq                                                    1          2
# ==============
# Dataset: Age & Sex Data
# ==============
#
# Shape:
# (73, 2)
#
# Columns:
# Index(['Vintage 2023 Annual Resident Population Estimates by Selected Age Groups and Sex: April 1, 2020 to July 1, 2023', 'Unnamed: 1'], dtype='object')
#
# Data Types:
# Vintage 2023 Annual Resident Population Estimates by Selected Age Groups and Sex: April 1, 2020 to July 1, 2023    object
# Unnamed: 1                                                                                                         object
# dtype: object
#
# Missing Values:
# Vintage 2023 Annual Resident Population Estimates by Selected Age Groups and Sex: April 1, 2020 to July 1, 2023    17
# Unnamed: 1                                                                                                         36
# dtype: int64
#
# Duplicate Rows:
# 9
#
# Summary Statistics:
#        Vintage 2023 Annual Resident Population Estimates by Selected Age Groups and Sex: April 1, 2020 to July 1, 2023  \
# count                                                  56
# unique                                                 56
# top     Note: The table shown may have been modified b...
# freq                                                    1
#
#                   Unnamed: 1
# count                     37
# unique                    33
# top     Population Estimates
# freq                       2
# ==============
# Dataset: Population Data
# ==============
#
# Shape:
# (43, 2)
#
# Columns:
# Index(['Total Population', 'Unnamed: 1'], dtype='object')
#
# Data Types:
# Total Population    object
# Unnamed: 1          object
# dtype: object
#
# Missing Values:
# Total Population    18
# Unnamed: 1          23
# dtype: int64
#
# Duplicate Rows:
# 9
#
# Summary Statistics:
#                                          Total Population Unnamed: 1
# count                                                  25         20
# unique                                                 25         19
# top     Note: The table shown may have been modified b...     B01003
# freq                                                    1          2

# %%
num_cols = housing.select_dtypes(include=np.number).columns

for col in num_cols:
    Q1 = housing[col].quantile(0.25)
    Q3 = housing[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    outliers = housing[(housing[col] < lower) | (housing[col] > upper)].shape[0]
    
    print(col, "Outliers:", outliers)
# Out:
# longitude Outliers: 0
# latitude Outliers: 0
# housing_median_age Outliers: 0
# total_rooms Outliers: 1287
# total_bedrooms Outliers: 1271
# population Outliers: 1196
# households Outliers: 1220
# median_income Outliers: 681
# median_house_value Outliers: 1071
